# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:1234@localhost:5432/data_jobs

# %%
# %%sql
#
#
# SELECT * FROM job_postings_fact LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/data_jobs
# 10 rows affected.
# [(4593, 4593, 'Data Analyst', 'Data Analyst', 'New York, NY', 'via CareerBuilder', 'Full-time', False, 'New York, United States', datetime.datetime(2023, 1, 1, 0, 0, 4), False, False, 'United States', None, None, None),
#  (4594, 4594, 'Data Analyst', 'Data Analyst', 'Washington, DC', 'via CareerBuilder', 'Full-time', False, 'New York, United States', datetime.datetime(2023, 1, 1, 0, 0, 22), False, True, 'United States', None, None, None),
#  (4595, 4595, 'Data Analyst', 'Data Analyst', 'Fairfax, VA', 'via CareerBuilder', 'Full-time', False, 'New York, United States', datetime.datetime(2023, 1, 1, 0, 0, 24), False, False, 'United States', None, None, None),
#  (4596, 4596, 'Senior Data Analyst', 'Senior Data Analyst / Platform Experience', 'Worcester, MA', 'via LinkedIn', 'Full-time', False, 'New York, United States', datetime.datetime(2023, 1, 1, 0, 0, 27), False, True, 'United States', None, None, None),
#  (4597, 4597, 'Data Analyst', 'Data Analyst', 'Sunnyvale, CA', 'via CareerBuilder', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 38), False, False, 'United States', None, None, None),
#  (4598, 4598, 'Data Analyst', 'Jr. Data Analyst', 'Torrance, CA', 'via Recruit.net', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 38), False, False, 'United States', None, None, None),
#  (4599, 4599, 'Data Analyst', 'Data Analyst', 'San Francisco, CA', 'via Jora', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 43), True, False, 'United States', None, None, None),
#  (4600, 4600, 'Data Analyst', 'Loyalty Data Analyst III', 'Pleasanton, CA', 'via Recruit.net', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 51), False, False, 'United States', None, None, None),
#  (4601, 4601, 'Senior Data Analyst', 'Senior data analyst', 'Rosemead, CA', 'via Talent.com', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 57), False, True, 'United States', None, None, None),
#  (4602, 4602, 'Business Analyst', 'Business Analyst - Taxonomy/Ontology', 'Thousand Oaks, CA', 'via CareerBuilder', 'Full-time', False, 'California, United States', datetime.datetime(2023, 1, 1, 0, 0, 57), False, False, 'United States', None, None, None)]

# %%
# %%sql
#
# SELECT
#     job_title,
#     job_title_short
# FROM job_postings_fact limit 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/data_jobs
# 10 rows affected.
# [('Data Analyst', 'Data Analyst'),
#  ('Data Analyst', 'Data Analyst'),
#  ('Data Analyst', 'Data Analyst'),
#  ('Senior Data Analyst / Platform Experience', 'Senior Data Analyst'),
#  ('Data Analyst', 'Data Analyst'),
#  ('Jr. Data Analyst', 'Data Analyst'),
#  ('Data Analyst', 'Data Analyst'),
#  ('Loyalty Data Analyst III', 'Data Analyst'),
#  ('Senior data analyst', 'Senior Data Analyst'),
#  ('Business Analyst - Taxonomy/Ontology', 'Business Analyst')]

# %%
# %%sql
#
#
#
# SELECT skills,
#     type,
#     COUNT(*) as demand_count
# FROM skills_dim
# GROUP BY skills,type
# ORDER BY demand_count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/data_jobs
# 259 rows affected.
# [('asp.netcore', 'webframeworks', 2),
#  ('powerbi', 'analyst_tools', 2),
#  ('sqlserver', 'databases', 2),
#  ('typescript', 'programming', 1),
#  ('excel', 'analyst_tools', 1),
#  ('esquisse', 'analyst_tools', 1),
#  ('mariadb', 'databases', 1),
#  ('haskell', 'programming', 1),
#  ('nosql', 'programming', 1),
#  ('r', 'programming', 1),
#  ('ubuntu', 'os', 1),
#  ('colocation', 'cloud', 1),
#  ('flutter', 'libraries', 1),
#  ('workzone', 'async', 1),
#  ('rubyon rails', 'webframeworks', 1),
#  ('twilio', 'sync', 1),
#  ('spring', 'libraries', 1),
#  ('aurora', 'cloud', 1),
#  ('t-sql', 'programming', 1),
#  ('digitalocean', 'cloud', 1),
#  ('shogun', 'libraries', 1),
#  ('svelte', 'webframeworks', 1),
#  ('fedora', 'os', 1),
#  ('qt', 'libraries', 1),
#  ('hadoop', 'libraries', 1),
#  ('dynamodb', 'databases', 1),
#  ('laravel', 'webframeworks', 1),
#  ('perl', 'programming', 1),
#  ('trello', 'async', 1),
#  ('mysql', 'databases', 1),
#  ('go', 'programming', 1),
#  ('fastify', 'webframeworks', 1),
#  ('theano', 'libraries', 1),
#  ('flask', 'webframeworks', 1),
#  ('c++', 'programming', 1),
#  ('crystal', 'programming', 1),
#  ('firebase', 'databases', 1),
#  ('power bi', 'analyst_tools', 1),
#  ('python', 'programming', 1),
#  ('spreadsheet', 'analyst_tools', 1),
#  ('chef', 'other', 1),
#  ('tableau', 'analyst_tools', 1),
#  ('play framework', 'webframeworks', 1),
#  ('dingtalk', 'async', 1),
#  ('heroku', 'cloud', 1),
#  ('rust', 'programming', 1),
#  ('graphql', 'libraries', 1),
#  ('erlang', 'programming', 1),
#  ('jenkins', 'other', 1),
#  ('ggplot2', 'libraries', 1),
#  ('matplotlib', 'libraries', 1),
#  ('docker', 'other', 1),
#  ('capacitor', 'libraries', 1),
#  ('mxnet', 'libraries', 1),
#  ('selenium', 'libraries', 1),
#  ('f#', 'programming', 1),
#  ('wsl', 'os', 1),
#  ('dart', 'programming', 1),
#  ('npm', 'other', 1),
#  ('ember.js', 'webframeworks', 1),
#  ('lua', 'programming', 1),
#  ('yarn', 'other', 1),
#  ('asp.net', 'webframeworks', 1),
#  ('apl', 'programming', 1),
#  ('notion', 'async', 1),
#  ('ssrs', 'analyst_tools', 1),
#  ('golang', 'programming', 1),
#  ('delphi', 'programming', 1),
#  ('vmware', 'cloud', 1),
#  ('couchdb', 'databases', 1),
#  ('opencv', 'libraries', 1),
#  ('kali', 'os', 1),
#  ('angular.js', 'webframeworks', 1),
#  ('pulumi', 'other', 1),
#  ('numpy', 'libraries', 1),
#  ('airflow', 'libraries', 1),
#  ('vb.net', 'programming', 1),
#  ('snowflake', 'cloud', 1),
#  ('pandas', 'libraries', 1),
#  ('seaborn', 'libraries', 1),
#  ('sharepoint', 'analyst_tools', 1),
#  ('vue', 'webframeworks', 1),
#  ('dlib', 'libraries', 1),
#  ('unreal', 'other', 1),
#  ('debian', 'os', 1),
#  ('visual basic', 'programming', 1),
#  ('confluence', 'async', 1),
#  ('splunk', 'analyst_tools', 1),
#  ('ms access', 'analyst_tools', 1),
#  ('react.js', 'webframeworks', 1),
#  ('firebase', 'cloud', 1),
#  ('php', 'programming', 1),
#  ('java', 'programming', 1),
#  ('nuix', 'analyst_tools', 1),
#  ('node', 'webframeworks', 1),
#  ('ruby on rails', 'webframeworks', 1),
#  ('html', 'programming', 1),
#  ('scala', 'programming', 1),
#  ('ssis', 'analyst_tools', 1),
#  ('redhat', 'os', 1),
#  ('planner', 'async', 1),
#  ('lisp', 'programming', 1),
#  ('microsoft lists', 'async', 1),
#  ('arch', 'os', 1),
#  ('express', 'webframeworks', 1),
#  ('swift', 'programming', 1),
#  ('linode', 'cloud', 1),
#  ('sas', 'analyst_tools', 1),
#  ('visio', 'analyst_tools', 1),
#  ('elixir', 'programming', 1),
#  ('blazor', 'webframeworks', 1),
#  ('windows', 'os', 1),
#  ('firestore', 'databases', 1),
#  ('c#', 'programming', 1),
#  ('ruby', 'programming', 1),
#  ('symphony', 'sync', 1),
#  ('hugging face', 'libraries', 1),
#  ('fortran', 'programming', 1),
#  ('atlassian', 'other', 1),
#  ('clickup', 'async', 1),
#  ('node.js', 'webframeworks', 1),
#  ('pascal', 'programming', 1),
#  ('css', 'programming', 1),
#  ('oracle', 'cloud', 1),
#  ('asana', 'async', 1),
#  ('cassandra', 'databases', 1),
#  ('julia', 'programming', 1),
#  ('suse', 'os', 1),
#  ('unix', 'os', 1),
#  ('dplyr', 'libraries', 1),
#  ('airtable', 'async', 1),
#  ('gcp', 'cloud', 1),
#  ('couchbase', 'databases', 1),
#  ('looker', 'analyst_tools', 1),
#  ('cobol', 'programming', 1),
#  ('puppet', 'other', 1),
#  ('pytorch', 'libraries', 1),
#  ('swit', 'async', 1),
#  ('neo4j', 'databases', 1),
#  ('matlab', 'programming', 1),
#  ('pyspark', 'libraries', 1),
#  ('react', 'libraries', 1),
#  ('word', 'analyst_tools', 1),
#  ('gatsby', 'webframeworks', 1),
#  ('huggingface', 'libraries', 1),
#  ('ringcentral', 'sync', 1),
#  ('scikit-learn', 'libraries', 1),
#  ('sap', 'analyst_tools', 1),
#  ('shell', 'programming', 1),
#  ('bash', 'programming', 1),
#  ('mlr', 'libraries', 1),
#  ('vue.js', 'webframeworks', 1),
#  ('centos', 'os', 1),
#  ('phoenix', 'webframeworks', 1),
#  ('kafka', 'libraries', 1),
#  ('aws', 'cloud', 1),
#  ('angular', 'webframeworks', 1),
#  ('rshiny', 'libraries', 1),
#  ('watson', 'cloud', 1),
#  ('mongodb', 'programming', 1),
#  ('unity', 'other', 1),
#  ('kotlin', 'programming', 1),
#  ('slack', 'sync', 1),
#  ('ansible', 'other', 1),
#  ('terminal', 'other', 1),
#  ('sql server', 'databases', 1),
#  ('sas', 'programming', 1),
#  ('microsoft teams', 'sync', 1),
#  ('dax', 'analyst_tools', 1),
#  ('symfony', 'webframeworks', 1),
#  ('gdpr', 'libraries', 1),
#  ('spark', 'libraries', 1),
#  ('assembly', 'programming', 1),
#  ('flow', 'other', 1),
#  ('redshift', 'cloud', 1),
#  ('electron', 'libraries', 1),
#  ('c', 'programming', 1),
#  ('monday.com', 'async', 1),
#  ('gitlab', 'other', 1),
#  ('outlook', 'analyst_tools', 1),
#  ('jupyter', 'libraries', 1),
#  ('workfront', 'async', 1),
#  ('macos', 'os', 1),
#  ('tidyverse', 'libraries', 1),
#  ('github', 'other', 1),
#  ('microstrategy', 'analyst_tools', 1),
#  ('openstack', 'cloud', 1),
#  ('fann', 'libraries', 1),
#  ('elasticsearch', 'databases', 1),
#  ('webex', 'sync', 1),
#  ('sass', 'programming', 1),
#  ('gtx', 'libraries', 1),
#  ('terraform', 'other', 1),
#  ('visualbasic', 'programming', 1),
#  ('google chat', 'sync', 1),
#  ('groovy', 'programming', 1),
#  ('fastapi', 'webframeworks', 1),
#  ('chainer', 'libraries', 1),
#  ('vba', 'programming', 1),
#  ('mongo', 'programming', 1),
#  ('asp.net core', 'webframeworks', 1),
#  ('redis', 'databases', 1),
#  ('cordova', 'libraries', 1),
#  ('ibm cloud', 'cloud', 1),
#  ('unify', 'sync', 1),
#  ('mattermost', 'sync', 1),
#  ('xamarin', 'libraries', 1),
#  ('clojure', 'programming', 1),
#  ('databricks', 'cloud', 1),
#  ('mlpack', 'libraries', 1),
#  ('objective-c', 'programming', 1),
#  ('msaccess', 'analyst_tools', 1),
#  ('tidyr', 'libraries', 1),
#  ('sql', 'programming', 1),
#  ('ionic', 'libraries', 1),
#  ('plotly', 'libraries', 1),
#  ('bigquery', 'cloud', 1),
#  ('codecommit', 'other', 1),
#  ('tensorflow', 'libraries', 1),
#  ('deno', 'webframeworks', 1),
#  ('db2', 'databases', 1),
#  ('qlik', 'analyst_tools', 1),
#  ('spss', 'analyst_tools', 1),
#  ('mongodb', 'databases', 1),
#  ('ruby', 'webframeworks', 1),
#  ('jira', 'async', 1),
#  ('no-sql', 'programming', 1),
#  ('powerpoint', 'analyst_tools', 1),
#  ('wimi', 'async', 1),
#  ('alteryx', 'analyst_tools', 1),
#  ('solidity', 'programming', 1),
#  ('git', 'other', 1),
#  ('azure', 'cloud', 1),
#  ('ocaml', 'programming', 1),
#  ('next.js', 'webframeworks', 1),
#  ('javascript', 'programming', 1),
#  ('homebrew', 'other', 1),
#  ('wire', 'sync', 1),
#  ('wrike', 'async', 1),
#  ('cognos', 'analyst_tools', 1),
#  ('smartsheet', 'async', 1),
#  ('ovh', 'cloud', 1),
#  ('datarobot', 'analyst_tools', 1),
#  ('powershell', 'programming', 1),
#  ('postgresql', 'databases', 1),
#  ('django', 'webframeworks', 1),
#  ('rocketchat', 'sync', 1),
#  ('keras', 'libraries', 1),
#  ('kubernetes', 'other', 1),
#  ('svn', 'other', 1),
#  ('sheets', 'analyst_tools', 1),
#  ('zoom', 'sync', 1),
#  ('linux', 'os', 1),
#  ('sqlite', 'databases', 1),
#  ('nuxt.js', 'webframeworks', 1),
#  ('nltk', 'libraries', 1),
#  ('drupal', 'webframeworks', 1),
#  ('bitbucket', 'other', 1),
#  ('jquery', 'webframeworks', 1)]

# %%
# %%sql
#
#
# SELECT *
# FROM skills_job_dim limit 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/data_jobs
# 10 rows affected.
# [(0, 4593),
#  (0, 4594),
#  (1, 4594),
#  (2, 4594),
#  (0, 4595),
#  (0, 4596),
#  (0, 4597),
#  (1, 4597),
#  (2, 4599),
#  (1, 4599)]

# %%
# %%sql
#
#
# SELECT *
# FROM company_dim LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/data_jobs
# 10 rows affected.
# [(4593, 'Metasys Technologies', None, 'https://www.google.com/search?gl=us&hl=en&q=Metasys+Technologies&sa=X&ved=0ahUKEwjNqO7e2KX8AhWJpXIEHTxXDe04ChCYkAII7wo', None),
#  (4594, 'Guidehouse', None, 'https://www.google.com/search?gl=us&hl=en&q=Guidehouse&sa=X&ved=0ahUKEwiosI_n2KX8AhUCm2oFHWzsD2k4RhCYkAIIxA0', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbmcC-pbCuIfuWurdAt73eWsxsaGZKSeN2xwC8&s=0'),
#  (4595, 'Protask', 'http://www.protaskinc.com/', 'https://www.google.com/search?q=Protask&sa=X&ved=0ahUKEwi_taTo2KX8AhVPmmoFHX-lBPY4UBCYkAIIzA0', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqzAaX7nypw1nvKthg8zBA1mwakyH-vlIVjLlC&s=0'),
#  (4596, 'Atria Wealth Solutions', 'http://www.atriawealth.com/', 'https://www.google.com/search?hl=en&gl=us&q=Atria+Wealth+Solutions&sa=X&ved=0ahUKEwja24Tq2KX8AhVdGVkFHTM4Bts4WhCYkAIIjg4', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWPMd1HioT6f6Ay00DqhVlCpTOaRY8d_I52yem0lE&s'),
#  (4597, 'ICONMA, LLC', 'http://www.iconma.com/', 'https://www.google.com/search?q=ICONMA,+LLC&sa=X&ved=0ahUKEwjy6p3w2KX8AhUwrHIEHRK5C_YQmJACCLQO', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSuUzhTtGXnUAQ50iypDbcoyQHqRY1cfdFerX9s&s=0'),
#  (4598, 'Aquent', 'http://aquent.com/', 'https://www.google.com/search?q=Aquent&sa=X&ved=0ahUKEwjy6p3w2KX8AhUwrHIEHRK5C_YQmJACCPIO', None),
#  (4599, 'Adyen', 'http://www.adyen.com/', 'https://www.google.com/search?hl=en&gl=us&q=Adyen&sa=X&ved=0ahUKEwjkr8Dz2KX8AhVCD1kFHYBJA_Q4ChCYkAII-w4', None),
#  (4600, 'Albertsons Companies', 'http://www.albertsonscompanies.com/', 'https://www.google.com/search?hl=en&gl=us&q=Albertsons+Companies&sa=X&ved=0ahUKEwjeysT12KX8AhX0UjUKHYF4DxU4FBCYkAII9ws', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJMMSM3JVIY8PKn3JqstTUcODytm3gCiug77YSW8Y&s'),
#  (4601, 'Panda Restaurant Group', 'http://www.pandarg.com/', 'https://www.google.com/search?gl=us&hl=en&q=Panda+Restaurant+Group&sa=X&ved=0ahUKEwir_vL32KX8AhWFMlkFHXFqDGE4KBCYkAII8go', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsZPYAJ9MDnx4qP0_krkqSBhzxp-Y-jzWnTGyq&s=0'),
#  (4602, 'Diverse Lynx', 'http://www.diverselynx.com/', 'https://www.google.com/search?gl=us&hl=en&q=Diverse+Lynx&sa=X&ved=0ahUKEwir_vL32KX8AhWFMlkFHXFqDGE4KBCYkAII5A0', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSqFxptto_wEQxlJ0l6jN8x57KBmzJAUjgQpDCy&s=0')]
